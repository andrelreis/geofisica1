# %% [markdown]
# # Testing animation plot

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriterb

# %%
# Generate some random points in 2D space
x = np.linspace(0.,10)

# Choosing a linear functiona
y = 2*x + 5

# %%
# Create the figure and axis
fig, ax = plt.subplots()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Scatter plot of all points
scatter = ax.scatter(points[:, 0], points[:, 1], c='black')

# Function to update the plot
def update(frame):
    ax.clear() 
    ax.scatter(points[:, 0], points[:, 1], c='black')  # Replot all points
    
    # Get the current point
    point = points[frame]
    
    # Find neighbors
    distances, indices = tree.query(point, k=num_neighbors + 1)  # +1 to include the point itself
    
    # Plot the neighbors
    for j in range(1, len(indices)):  # Start from 1 to skip the point itself
        neighbor = points[indices[j]]
        ax.plot([point[0], neighbor[0]], [point[1], neighbor[1]], 'r-')  # Connect with a line
        ax.scatter(neighbor[0], neighbor[1], c='red')  # Highlight the neighbor
    
    ax.set_title(f'Point {frame}: {point}')

# Create the animation
ani = FuncAnimation(fig, update, frames=len(points), interval=300, repeat=False)
ani.save('points_neighbours.gif', writer=PillowWriter(fps=2))

plt.show()  # Display the plot
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
